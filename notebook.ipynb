# %% [markdown]
# # Proyek Analisis Data: E-Commerce Public Dataset
# - Nama: Gilang Nur Rizki
# - Email: gilangnurrizki173@gmail.com
# - Id Dicoding: gilang_nurrizki

# %% [markdown]
# ## Menentukan pertanyaan bisnis
# 1. Apa produk yang paling banyak dibeli dan paling sedikit dibeli?
# 2. Bagaimana tingkat kepuasan pembeli terhadap layanan?
# 3. Kota mana yang memiliki seller dan customer paling banyak?
# 4. Metode pembayaran mana yang digunakan untuk jumlah pembayaran terbesar? Berapa besarnya nilai pembayarannya?

# %% [markdown]
# ## Menyiapkkan semua library yang dibutuhkan

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import datetime as dt
import matplotlib.ticker as mtick

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
customer_df = pd.read_csv('DATA/customers_dataset.csv')
customer_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
geolocation_df = pd.read_csv('DATA/geolocation_dataset.csv')
geolocation_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
order_items_df = pd.read_csv('DATA/order_items_dataset.csv')
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
order_payments_df = pd.read_csv('DATA/order_payments_dataset.csv')
order_payments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_reviews_df = pd.read_csv('DATA/order_reviews_dataset.csv')
order_reviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
orders_df = pd.read_csv('DATA/orders_dataset.csv')
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
product_category_name_df = pd.read_csv('DATA/product_category_name_translation.csv')
product_category_name_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
products_df = pd.read_csv('DATA/products_dataset.csv')
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
sellers_df = pd.read_csv('DATA/sellers_dataset.csv')
sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# ### Assesing Data

# %% [markdown]
# #### Menilai tabel `customers_df`

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
customer_df.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
print('Jumlah duplikasi: ', customer_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
customer_df.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# #### Menilai tabel `geolocation_df`

# %%
geolocation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
geolocation_df.isna().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
print('Jumlah duplikasi: ', geolocation_df.duplicated().sum())
geolocation_df.describe()
# Out:
# Jumlah duplikasi:  261831
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                 1.000163e+06     1.000163e+06     1.000163e+06
# mean                  3.657417e+04    -2.117615e+01    -4.639054e+01
# std                   3.054934e+04     5.715866e+00     4.269748e+00
# min                   1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                   1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                   2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                   6.350400e+04    -1.997962e+01    -4.376771e+01
# max                   9.999000e+04     4.506593e+01     1.211054e+02

# %% [markdown]
# #### Menilai tabel `order_items_df`

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
order_items_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
print('Jumlah duplikasi: ', order_items_df.duplicated().sum())
order_items_df.describe()
# Out:
# Jumlah duplikasi:  0
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# #### Menilai tabel `order_payments_df`

# %%
order_payments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
order_payments_df.isna().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
print('Jumlah duplikasi: ', order_payments_df.duplicated().sum())
order_payments_df.describe()
# Out:
# Jumlah duplikasi:  0
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %% [markdown]
# #### Menilai tabel `order_reviews_df`

# %%
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
print('Jumlah duplikasi: ', order_reviews_df.duplicated().sum())
order_reviews_df.describe()
# Out:
# Jumlah duplikasi:  0
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %% [markdown]
# #### Menilai tabel `orders_df`

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
print('Jumlah duplikasi: ', orders_df.duplicated().sum())
orders_df.describe()
# Out:
# Jumlah duplikasi:  0
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %% [markdown]
# #### Menilai tabel `products_df`

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
print('Jumlah duplikasi: ', products_df.duplicated().sum())
products_df.describe()
# Out:
# Jumlah duplikasi:  0
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %% [markdown]
# #### Menilai tabel `product_category_name`

# %%
product_category_name_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
product_category_name_df.isna().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
print('Jumlah duplikasi: ', product_category_name_df.duplicated().sum())
product_category_name_df.describe()
# Out:
# Jumlah duplikasi:  0
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %% [markdown]
# #### Menilai tabel `sellers_df`

# %%
sellers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
sellers_df.isna().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
print('Jumlah duplikasi: ', sellers_df.duplicated().sum())
sellers_df.describe()
# Out:
# Jumlah duplikasi:  0
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Menghapus data duplikasi pada `geolocation_df`

# %%
geolocation_df.duplicated().sum()
# Out:
# 261831

# %%
geolocation_df.drop_duplicates(inplace=True)

# %%
geolocation_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Mengganti tipe data menjadi datetime pada tabel `order_item_df`, `order_review_df`, dan `orders_df`

# %%
dt_order_item = ['shipping_limit_date']
for column in dt_order_item:
    order_items_df[column] = pd.to_datetime(order_items_df[column])

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
dt_order_review = ['review_creation_date', 'review_answer_timestamp']
for column in dt_order_review:
    order_reviews_df[column] = pd.to_datetime(order_reviews_df[column])

# %%
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 5.3+ MB

# %%
dt_orders = [
    'order_purchase_timestamp',
    'order_approved_at',
    'order_delivered_carrier_date',
    'order_delivered_customer_date',
    'order_estimated_delivery_date'
]
for column in dt_orders:
    orders_df[column] = pd.to_datetime(orders_df[column])

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %% [markdown]
# #### Mengisi missing values pada tabel `order_review_df`, `product_df`, & `orders_df`

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %% [markdown]
# Mengisi missing value dengan nilai defaul "No Title" & "No Message"

# %%
order_reviews_df['review_comment_title'].fillna("No Title", inplace=True)
order_reviews_df['review_comment_message'].fillna("No Message", inplace=True)

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                  0
# order_id                   0
# review_score               0
# review_comment_title       0
# review_comment_message     0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64

# %%
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %% [markdown]
# Mengisi mising value dengan "Others" untuk kolom product_category_name dan sisanya diisi dengan median dari masing-masing kolom yang mengandung missing value.

# %%
products_df['product_category_name'].fillna('Others', inplace=True)

# %%
numeric_columns = products_df.select_dtypes(include=[np.number]) # Memilih kolom numerik
products_df[numeric_columns.columns] = products_df[numeric_columns.columns].fillna(numeric_columns.median())

# %%
products_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %% [markdown]
# Mengisi missing value pada `orders_df` dengan metode ffill()

# %%
orders_df.ffill(inplace=True)

# %%
orders_df.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %% [markdown]
# #### Mengexplore tabel `customers_df`

# %%
customer_df.describe(include='all')
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %% [markdown]
# Mengetahui bahwa tabel `customer_df` memiliki nilai yang unik

# %%
customer_df.customer_id.is_unique
# Out:
# True

# %% [markdown]
# Mengetahui dari kota mana pelanggan berasal yang paling dominan

# %%
customer_df.groupby(by='customer_city')['customer_id'].nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %% [markdown]
# #### Mengeksplore tabel `order_payment_df`

# %%
order_payments_df
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %% [markdown]
# Melihat jenis pembayaran terbanyak

# %%
order_payments_df.groupby(by='payment_type')['order_id'].size().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# not_defined        3
# Name: order_id, dtype: int64

# %% [markdown]
# Melihat payment value terbesar

# %%
order_payments_df.sort_values(by='payment_value', ascending=False)
# Out:
#                                order_id  payment_sequential payment_type  \
# 52107  03caa2c082116e1d31e67e9ae3700499                   1  credit_card
# 34370  736e1922ae60d0d6a89247b851902527                   1       boleto
# 41419  0812eb902a67711a1cb742b3cdaa65ae                   1  credit_card
# 49581  fefacc66af859508bf1a7934eab1e97f                   1       boleto
# 85539  f5136e38d1a14a4dbd87dff67da82701                   1       boleto
# ...                                 ...                 ...          ...
# 43744  6ccb433e00daae1283ccc956189c82ae                   4      voucher
# 62674  45ed6e85398a87c253db47c2d9f48216                   3      voucher
# 19922  8bcbe01d44d147f901cd3192671144db                   4      voucher
# 94427  c8c528189310eaa44a745b8d9d26908b                   1  not_defined
# 77885  fa65dad1b0e818e3ccc5cb0e39231352                  13      voucher
#
#        payment_installments  payment_value
# 52107                     1       13664.08
# ...

# %% [markdown]
# ####  Explore All data

# %% [markdown]
# Menggabungkan tabel `customer_df` dan `orders_df`

# %%
customer_orders_df = pd.merge(
    left=customer_df,
    right=orders_df,
    how='left',
    left_on='customer_id',
    right_on='customer_id'
)
customer_orders_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %% [markdown]
# Menggabungkan tabel `products_df` dan `product_category_name_df`

# %%
new_products_df = pd.merge(
    left=products_df,
    right=product_category_name_df,
    how='left',
    left_on='product_category_name',
    right_on='product_category_name'
)

# %%
column = new_products_df.pop('product_category_name_english')
new_products_df.insert(2, column.name, column)
new_products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#   product_category_name_english  product_name_lenght  \
# 0                     perfumery                 40.0
# 1                           art                 44.0
# 2                sports_leisure                 46.0
# 3                          baby                 27.0
# 4                    housewares                 37.0
#
#    product_description_lenght  product_photos_qty  product_weight_g  \
# 0                       287.0                 1.0             225.0
# 1                       276.0                 1.0            1000.0
# 2                       250.0                 1.0             154.0
# ...

# %% [markdown]
# Menggabungkan tabel `customer_order_df` dan `order_payment_df`

# %%
merge1 = pd.merge(
    left=customer_orders_df,
    right=order_payments_df,
    how='left',
    left_on='order_id',
    right_on='order_id'
)
merge1.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %% [markdown]
# Menggabungkan semua tabel

# %%
merge2 = pd.merge(
    left=merge1,
    right=order_items_df,
    how='left',
    left_on='order_id',
    right_on='order_id'
)
merge2.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
merge3 = pd.merge(
    left=merge2,
    right=new_products_df,
    how='left',
    left_on='product_id',
    right_on='product_id'
)
merge3.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
merge4 = pd.merge(
    left=merge3,
    right=sellers_df,
    how='left',
    left_on='seller_id',
    right_on='seller_id'
)
merge4.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
all_df = pd.merge(
    left=merge4,
    right=order_reviews_df,
    how='left',
    left_on='order_id',
    right_on='order_id'
)
all_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
all_df.describe()
# Out:
#        customer_zip_code_prefix       order_purchase_timestamp  \
# count             119143.000000                         119143
# mean               35033.451298  2017-12-29 18:36:13.115760384
# min                 1003.000000            2016-09-04 21:15:19
# 25%                11250.000000            2017-09-10 20:15:46
# 50%                24240.000000            2018-01-17 11:59:12
# 75%                58475.000000            2018-05-03 13:18:30
# max                99990.000000            2018-10-17 17:30:18
# std                29823.198969                            NaN
#
#                    order_approved_at   order_delivered_carrier_date  \
# count                         119143                         119143
# mean   2017-12-30 06:27:12.319137280  2018-01-03 11:58:02.865640192
# min              2016-09-15 12:16:38            2016-10-08 10:34:01
# 25%              2017-09-11 17:44:36     2017-09-14 20:32:23.500000
# ...

# %% [markdown]
# Menampilkan total laba berdasarkan negara bagian untuk setiap kategori produk.

# %%
all_df.groupby(by=['customer_state', 'product_category_name_english']).agg({
    'price' : 'sum',
}).sort_values(by='price', ascending=False)
# Out:
#                                                   price
# customer_state product_category_name_english
# SP             bed_bath_table                 509313.30
#                health_beauty                  475928.29
#                watches_gifts                  450822.51
#                sports_leisure                 403732.12
#                computers_accessories          360210.34
# ...                                                 ...
# AL             drinks                             15.49
# BA             home_comfort_2                     12.90
# ES             home_comfort_2                     12.90
# PR             home_comfort_2                     12.90
# MS             costruction_tools_tools             6.80
#
# [1356 rows x 1 columns]

# %% [markdown]
# Melihat tingkat jumlah kepuasan pembeli

# %%
all_df.groupby(by=['review_score'])['customer_id'].size().reset_index().sort_values(by='review_score', ascending=False)
# Out:
#    review_score  customer_id
# 4           5.0        66343
# 3           4.0        22319
# 2           3.0         9894
# 1           2.0         4162
# 0           1.0        15428

# %% [markdown]
# #### RFM

# %%
today=dt.datetime(2018,10,20)

# %%
all_df['order_purchase_timestamp'] = pd.to_datetime(all_df['order_purchase_timestamp'])

# Group by 'customer_id' and calculate Recency, Frequency, and Monetary
recency = (today - all_df.groupby('customer_id')['order_purchase_timestamp'].max()).dt.days
frequency = all_df.groupby('customer_id')['order_id'].count()
monetary = all_df.groupby('customer_id')['price'].sum()

# Create a new DataFrame with the calculated metrics
rfm_df = pd.DataFrame({
    'customer_id': recency.index,
    'Recency': recency.values,
    'Frequency': frequency.values,
    'Monetary': monetary.values
})

# %%
column_list = ['customer_id','Recency','Frequency','Monetary']
rfm_df.columns = column_list

# %% [markdown]
# Customer dengan pengeluaran terbesar

# %%
rfm_df.sort_values(by='Monetary', ascending=False)
# Out:
#                             customer_id  Recency  Frequency  Monetary
# 8546   1617b1357756262bfa56ab541c47bc16      385          8  13440.00
# 60184  9af2372a1e49340278e7c1ef8d749f34      547         29  11383.95
# 86603  de832e8dbb1f588a47013e53feaa67cc      508         15  10856.10
# 38590  63b964e79dee32a3587651701a2b8dbf      247         24   9888.00
# 43009  6f241d5bbb142b6f764387c8c270645a      162          7   9520.14
# ...                                 ...      ...        ...       ...
# 70386  b4bade0909a2956cbeef036f6fd7b95e      274          1      0.00
# 33389  5645f6b97d3740bc2846f27af1fe973f      218          1      0.00
# 70474  b4f3d737d8ec2ad8a4e85fc6e578a4fc      434          1      0.00
# 33344  56252fddbb6af46b87f5a070d68afd95      166          1      0.00
# 99440  ffffe8b65bbe3087b653a978c870db99      385          1      0.00
#
# [99441 rows x 4 columns]

# %% [markdown]
# Customer dengan terakhir kali belanja

# %%
rfm_df.sort_values(by='Recency', ascending=False)
# Out:
#                             customer_id  Recency  Frequency  Monetary
# 3354   08c5351a6aca1c1589a38f244edeee9d      775          2     72.89
# 40289  683c54fc24d40ee9f8a6fc179fd9856c      774          1     59.50
# 38013  622e13439d6b5a0b486c435618b2679e      766          1      0.00
# 52277  86dc2ffce2dfff336de2f386a786e574      764          3    134.97
# 68946  b106b360fe2ef8849fbbd056f777b4d5      747          1    100.00
# ...                                 ...      ...        ...       ...
# 15595  2823ffda607a2316375088e0d00005ec       20          1      0.00
# 74611  bf6181a85bbb4115736c0a8db1a53be3       18          1      0.00
# 29531  4c2ec60c29d10c34bd49cb88aa85cfc4       16          1      0.00
# 51713  856336203359aa6a61bf3826f7d84c49        3          1      0.00
# 63970  a4b417188addbc05b26b72d5e44837a1        2          1      0.00
#
# [99441 rows x 4 columns]

# %% [markdown]
# Customer dengan jumlah belanja terbanyak

# %%
rfm_df.sort_values(by='Frequency', ascending=False)
# Out:
#                             customer_id  Recency  Frequency  Monetary
# 15183  270c23a11d024a44c896d1894b261a83      437         63   2305.38
# 7586   13aa59158da63ba0e93ec6ac2c07aacb      391         38   3039.62
# 60184  9af2372a1e49340278e7c1ef8d749f34      547         29  11383.95
# 56942  92cd3ec6e2d643d4ebd0e3d6238f69e2      499         26   1299.74
# 81894  d22f25a9fadfb1abbc2e29395b1239f4      160         24    359.76
# ...                                 ...      ...        ...       ...
# 35433  5b9d5dfe6b754261741fb68772efed93      258          1     22.99
# 35432  5b99d2ac45d9e913fa37e13a7e73f1fc      458          1     59.90
# 35431  5b985c8b77fba94494956d5f1e717933      164          1    120.00
# 35429  5b97e86cf344fc8159321fe9a84dbef9      537          1    139.90
# 99440  ffffe8b65bbe3087b653a978c870db99      385          1      0.00
#
# [99441 rows x 4 columns]

# %%
all_df.to_csv('all_data.csv', index=False)

# %% [markdown]
# ### Visualization & Explanatory Analysis

# %% [markdown]
# #### Pertanyaan 1: Apa produk yang paling banyak dibeli dan paling sedikit dibeli?

# %%
product_counts = all_df.groupby('product_category_name_english')['product_id'].count().reset_index()
sorted_df = product_counts.sort_values(by='product_id', ascending=False)
sorted_df
# Out:
#    product_category_name_english  product_id
# 7                 bed_bath_table       11988
# 43                 health_beauty       10032
# 65                sports_leisure        9004
# 39               furniture_decor        8832
# 15         computers_accessories        8150
# ..                           ...         ...
# 3          arts_and_craftmanship          24
# 52                    la_cuisine          16
# 11             cds_dvds_musicals          14
# 29     fashion_childrens_clothes           8
# 61         security_and_services           2
#
# [71 rows x 2 columns]

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x="product_id", y="product_category_name_english", hue="product_category_name_english", data=sorted_df.head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Products with the highest sales", loc="center", fontsize=19)
ax[0].tick_params(axis='y', labelsize=15)

sns.barplot(x="product_id", y="product_category_name_english", hue="product_category_name_english", data=sorted_df.sort_values(by="product_id", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Products with the lowest sales", loc="center", fontsize=19)
ax[1].tick_params(axis='y', labelsize=15)

plt.suptitle("Most and Least Sold Products", fontsize=28)
plt.show()

# %% [markdown]
# #### Pertanyaan 2: Bagaimana tingkat kepuasan pembeli terhadap layanan?

# %%
rating_service = all_df['review_score'].value_counts().sort_values(ascending=False)
max_score = rating_service.idxmax()

colors = ["#72BCD4" if score == max_score else "#D3D3D3" for score in rating_service.index]

sns.set(style="darkgrid")

plt.figure(figsize=(10, 5))
sns.barplot(x=rating_service.index, 
            y=rating_service.values, 
            order=rating_service.index,
            palette=colors
            )

plt.title("Rating customers for service", fontsize=15)
plt.xlabel("Rating")
plt.ylabel("Customer")
plt.xticks(fontsize=12)
plt.show()
# Out:
# C:\Users\gilan\AppData\Local\Temp\ipykernel_5064\3595047942.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=rating_service.index,

# %% [markdown]
# #### Pertanyaan 3: Kota mana yang memiliki seller dan customer paling banyak?

# %%
city_customer = all_df.customer_city.value_counts().sort_values(ascending=False).rename_axis('City').reset_index(name='Number of Customers') 
city_customer
# Out:
#                    City  Number of Customers
# 0             sao paulo                18875
# 1        rio de janeiro                 8311
# 2        belo horizonte                 3299
# 3              brasilia                 2500
# 4              curitiba                 1827
# ...                 ...                  ...
# 4114  sao jorge d'oeste                    1
# 4115         nova araca                    1
# 4116              ajapi                    1
# 4117            trabiju                    1
# 4118  eugenio de castro                    1
#
# [4119 rows x 2 columns]

# %%
top_5_cities_customer = city_customer.head(5)
plt.figure(figsize=(10, 6))
colors = ["#72BCD4" if city == top_5_cities_customer['City'].iloc[0] else "#D3D3D3" for city in top_5_cities_customer['City']]
sns.barplot(x="Number of Customers", y="City", data=top_5_cities_customer, hue=top_5_cities_customer['City'], palette=colors, legend=False)
plt.xlabel('Number of Customers')
plt.ylabel('City')
plt.title('Top 5 Cities with the Most Customers')

plt.show()

# %%
city_seller = all_df.seller_city.value_counts().sort_values(ascending=False).rename_axis('City').reset_index(name='Number of Sellers')
city_seller
# Out:
#                       City  Number of Sellers
# 0                sao paulo              29293
# 1                 ibitinga               8373
# 2                 curitiba               3161
# 3              santo andre               3149
# 4    sao jose do rio preto               2693
# ..                     ...                ...
# 606          serra redonda                  1
# 607           sao paulo sp                  1
# 608    sao miguel do oeste                  1
# 609          guaratingueta                  1
# 610                    sbc                  1
#
# [611 rows x 2 columns]

# %%
top_5_cities = city_seller.head(5)
plt.figure(figsize=(10, 6))
colors = ["#72BCD4" if city == top_5_cities['City'].iloc[0] else "#D3D3D3" for city in top_5_cities['City']]
sns.barplot(x="Number of Sellers", y="City", data=top_5_cities, hue=top_5_cities['City'], palette=colors, legend=False)
plt.xlabel('Number of Sellers')
plt.ylabel('City')
plt.title('Top 5 Cities with the Most Sellers')

plt.show()

# %% [markdown]
# #### Pertanyaan 4: Metode pembayaran mana yang digunakan untuk jumlah pembayaran terbesar? Berapa besarnya nilai pembayarannya?

# %%
total_payment_type = all_df.groupby('payment_type')['payment_value'].sum().reset_index()
total_payment_type
# Out:
#   payment_type  payment_value
# 0       boleto     4110920.74
# 1  credit_card    15775450.54
# 2   debit_card      257374.89
# 3  not_defined           0.00
# 4      voucher      435917.84

# %%
# Konversi nilai ke format "M" (juta)
total_payment_type['payment_value_million'] = total_payment_type['payment_value'] / 1e6
plt.figure(figsize=(10, 6))
sns.barplot(x="payment_type", y="payment_value_million", data=total_payment_type, palette="Blues_d")
plt.xlabel('Payment Type')
plt.ylabel('Total Payment Value (Million)')
plt.title('Total Payment Value by Payment Type')

# Menambahkan format label sumbu y
fmt = '{x:,.0f}M'
tick = mtick.StrMethodFormatter(fmt)
plt.gca().yaxis.set_major_formatter(tick)
plt.show()
# Out:
# C:\Users\gilan\AppData\Local\Temp\ipykernel_5064\2847672247.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="payment_type", y="payment_value_million", data=total_payment_type, palette="Blues_d")

# %% [markdown]
# #### Visualisasi untuk RFM

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(30, 6))
colors = ["#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4"]

# Visualisasi berdasarkan Recency
sns.barplot(y="Recency", x="customer_id", data=rfm_df.sort_values(by="Recency", ascending=True).head(5), ax=ax[0], color=colors[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel("customer_id")
ax[0].set_title("By Recency (days)", loc="center", fontsize=18)
ax[0].tick_params(axis ='x', labelsize=15)
ax[0].set_xticks([])

# Visualisasi berdasarkan Frequency
sns.barplot(y="Frequency", x="customer_id", data=rfm_df.sort_values(by="Frequency", ascending=False).head(5), ax=ax[1], color=colors[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel('customer_id')
ax[1].set_title("By Frequency", loc="center", fontsize=18)
ax[1].tick_params(axis='x', labelsize=15)
ax[1].set_xticks([])

# Visualisasi berdasarkan Monetary
sns.barplot(y="Monetary", x="customer_id", data=rfm_df.sort_values(by="Monetary", ascending=False).head(5), ax=ax[2], color=colors[2])
ax[2].set_ylabel(None)
ax[2].set_xlabel('customer_id')
ax[2].set_title("By Monetary", loc="center", fontsize=18)
ax[2].tick_params(axis='x', labelsize=15)
ax[2].set_xticks([])

plt.suptitle("Best Customer Based on RFM Parameters (customer_id)", fontsize=20)
plt.show()

# %% [markdown]
# ### Conclusion

# %% [markdown]
# #### 1. Apa produk yang paling banyak dibeli dan paling sedikit dibeli?

# %% [markdown]
# Berdasarkan data yang sudah divisualisasikan dapat terlihat dengan jelas bahwa barang yang paling banyak dibeli adalah **bed_bath_table** dan barang yang paling sedikit dibeli adalah **security_and_services**

# %% [markdown]
# #### 2. Bagaimana tingkat kepuasan pembeli terhadap layanan?

# %% [markdown]
# Sebagian besar pelanggan mengungkapkan tingkat kepuasan yang sangat tinggi, dan hal ini dapat dilihat dari data yang telah visualisasikan. Sebagian besar dari mereka memberikan peringkat maksimal, yaitu nilai 5, dalam penilaian mereka terhadap layanan atau produk tersebut. Dengan kata lain, kebanyakan pelanggan merasa sangat puas dengan layanan atau produk yang sediakan, dan ini tercermin dalam peringkat tinggi yang mereka berikan.

# %% [markdown]
# #### 3. Kota mana yang memiliki seller dan customer paling banyak?

# %% [markdown]
# Dalam data yang telah divisualisasikan, dapat dilihat bahwa kota dengan jumlah pelanggan terbanyak adalah Sao Paulo, dengan total pelanggan mencapai 18.875. Kota ini diikuti oleh Rio de Janeiro, Belo Horizonte, Brasília, dan Curitiba dalam urutan selanjutnya. Sementara itu, ketika melihat jumlah penjual, Sao Paulo juga mendominasi dengan total 29.293 penjual, diikuti oleh Ibtinga, Curitiba, Santo Andre, dan Sao Jose do Rio Preto.

# %% [markdown]
# #### 4. Metode pembayaran mana yang digunakan untuk jumlah pembayaran terbesar? Berapa besarnya nilai pembayarannya?

# %% [markdown]
# Dari data visualisasi yang telah tersaji, terlihat bahwa metode pembayaran yang paling banyak digunakan untuk jumlah pembayaran terbesar adalah melalui boleto, dengan total nilai pembayaran mencapai 4.110.920,74. Selanjutnya, metode pembayaran dengan kartu kredit mengikuti dengan total nilai pembayaran sebesar 15.775.450,54, diikuti oleh metode pembayaran dengan kartu debit dengan total nilai pembayaran sebesar 257.374,89.
